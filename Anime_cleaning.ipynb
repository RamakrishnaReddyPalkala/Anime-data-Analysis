# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\santh\OneDrive\Desktop\DS\Web Scrapping\Raw_Data_anime.csv")

# %%
df
# Out:
#      Unnamed: 0                                             Titles     Tv  \
# 0             0                   Fullmetal Alchemist: Brotherhood     TV
# 1             1                                        Steins;Gate     TV
# 2             2                                           Gintama°     TV
# 3             3                 Shingeki no Kyojin Season 3 Part 2     TV
# 4             4                                 Gintama: The Final  Movie
# ..          ...                                                ...    ...
# 395         395                                    Ashita no Joe 2     TV
# 396         396  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...     TV
# 397         397                                 Mob Psycho 100 III     TV
# 398         398  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...    NaN
# 399         399                                          86 Part 2     TV
#
#          Ep        SD         Ed  Ratings  \
# 0    64 eps  Apr 2009   Jul 2010     9.09
# 1    24 eps  Apr 2011   Sep 2011     9.07
# 2    51 eps  Apr 2015   Mar 2016     9.06
# 3    10 eps  Apr 2019   Jul 2019     9.05
# 4       NaN  Jan 2021   Jan 2021     9.04
# ..      ...       ...        ...      ...
# 395  47 eps  Oct 1980   Aug 1981     8.72
# 396  12 eps  Jan 2017   Mar 2017     8.71
# 397  12 eps  Oct 2022   Dec 2022     8.71
# 398     NaN  Feb 1999   Sep 1999     8.70
# 399  12 eps  Oct 2021   Mar 2022     8.70
#
#                                                 Genres       Source  \
# 0    ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...        Manga
# 1    ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...        Drama
# 2    ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...        Manga
# 3    ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...        Manga
# 4    ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...        Manga
# ..                                                 ...          ...
# 395    ['Drama', 'Sports', 'Combat Sports', 'Shounen']        Manga
# 396  ['Drama', 'Adult Cast', 'Historical', 'Love Po...        Manga
# 397  ['Action', 'Comedy', 'Supernatural', 'Super Po...    Web manga
# 398  ['Action', 'Drama', 'Romance', 'Adult Cast', '...        Manga
# 399  ['Action', 'Drama', 'Sci-Fi', 'Mecha', 'Milita...  Light novel
#
#        Demographic                                          Producers
# 0          Shounen  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1    Not specified  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 2          Shounen                  ['TV Tokyo', 'Aniplex', 'Dentsu']
# 3          Shounen  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 4          Shounen  ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...
# ..             ...                                                ...
# 395        Shounen                                       ['Annapuru']
# 396          Josei  ['Mainichi Broadcasting System', 'Kodansha', '...
# 397  Not specified  ['Shogakukan-Shueisha Productions', 'Warner Br...
# 398        Shounen                                        ['Aniplex']
# 399  Not specified          ['Aniplex', 'Kadokawa', 'Bandai Spirits']
#
# [400 rows x 11 columns]

# %% [markdown]
# # About this dataset
#
# This dataset contains 400 anime records scraped from the source site.
# Each row represents an anime and includes the following fields:
#
# - `Titles`: anime title (string)
# - `Tv`: format type (TV, Movie, OVA, etc.)
# - `Ep`: episode count
# - `SD`: start date / season
# - `Ed`: end date
# - `Ratings`: numeric rating (float)
# - `Genres`: list-like string of genres
# - `Source`: source material (Manga, Original, Light novel, etc.)
# - `Demographic`: target demographic (Shounen, Seinen, etc.)
# - `Producers`: list-like string of producers

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Titles', 'Tv', 'Ep', 'SD', 'Ed', 'Ratings', 'Genres',
#        'Source', 'Demographic', 'Producers'],
#       dtype='object')

# %% [markdown]
# ### summary of data types & missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   400 non-null    int64
#  1   Titles       400 non-null    object
#  2   Tv           374 non-null    object
#  3   Ep           276 non-null    object
#  4   SD           400 non-null    object
#  5   Ed           386 non-null    object
#  6   Ratings      400 non-null    float64
#  7   Genres       400 non-null    object
#  8   Source       400 non-null    object
#  9   Demographic  400 non-null    object
#  10  Producers    400 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 34.5+ KB

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.reset_index(drop=True)

# %%
###numeric stats (like Ratings)

# %%
df.describe()
# Out:
#           Ratings
# count  400.000000
# mean     8.850875
# std      0.104344
# min      8.700000
# 25%      8.760000
# 50%      8.820000
# 75%      8.930000
# max      9.090000

# %% [markdown]
# ### unique values for each categorical column

# %%
# df['Tv'].value_counts()
# df['Source'].value_counts()
# df['Demographic'].value_counts()

# %%
for col in ['Tv','Source','Demographic']:
    print(f"\nColumn: {col}")
    print(df[col].unique())
# Out:
# Column: Tv
# ['TV' 'Movie' nan]
#
# Column: Source
# ['Manga' 'Drama' 'Light novel' 'Action' 'Award Winning' 'Web manga'
#  '4-koma manga' 'Adventure']
#
# Column: Demographic
# ['Shounen' 'Not specified' 'Seinen' 'Shoujo' 'Josei']

# %%
print("Unique titles:", df['Titles'].nunique())
print("Unique genres strings:", df['Genres'].nunique())
print("Unique producers strings:", df['Producers'].nunique())
# Out:
# Unique titles: 57
# Unique genres strings: 41
# Unique producers strings: 49

# %%
# Missing values count
missing_count = df.isnull().sum()

# Missing values percentage
missing_pct = (df.isnull().mean() * 100).round(2)

# Combine into one table
missing_table = pd.DataFrame({
    'Missing Values': missing_count,
    'Missing %': missing_pct
})

missing_table
# Out:
#              Missing Values  Missing %
# Titles                    0        0.0
# Tv                       26        6.5
# Ep                      124       31.0
# SD                        0        0.0
# Ed                       14        3.5
# Ratings                   0        0.0
# Genres                    0        0.0
# Source                    0        0.0
# Demographic               0        0.0
# Producers                 0        0.0

# %%
# identify all object (text) columns
text_cols = df.select_dtypes(include='object').columns

# clean each text column
for col in text_cols:
    df[col] = df[col].apply(
        lambda x: str(x).replace('\xa0', ' ').strip() if pd.notna(x) else np.nan
    )

# %%
df.head()
# Out:
#                                Titles     Tv      Ep        SD        Ed  \
# 0    Fullmetal Alchemist: Brotherhood     TV  64 eps  Apr 2009  Jul 2010
# 1                         Steins;Gate     TV  24 eps  Apr 2011  Sep 2011
# 2                            Gintama°     TV  51 eps  Apr 2015  Mar 2016
# 3  Shingeki no Kyojin Season 3 Part 2     TV  10 eps  Apr 2019  Jul 2019
# 4                  Gintama: The Final  Movie     NaN  Jan 2021  Jan 2021
#
#    Ratings                                             Genres Source  \
# 0     9.09  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...  Manga
# 1     9.07  ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...  Drama
# 2     9.06  ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...  Manga
# 3     9.05  ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...  Manga
# 4     9.04  ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...  Manga
#
#      Demographic                                          Producers
# 0        Shounen  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1  Not specified  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 2        Shounen                  ['TV Tokyo', 'Aniplex', 'Dentsu']
# 3        Shounen  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 4        Shounen  ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Titles       400 non-null    object
#  1   Tv           374 non-null    object
#  2   Ep           276 non-null    object
#  3   SD           400 non-null    object
#  4   Ed           386 non-null    object
#  5   Ratings      400 non-null    float64
#  6   Genres       400 non-null    object
#  7   Source       400 non-null    object
#  8   Demographic  400 non-null    object
#  9   Producers    400 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 31.4+ KB

# %%
df.isna().sum()
# Out:
# Titles           0
# Tv              26
# Ep             124
# SD               0
# Ed              14
# Ratings          0
# Genres           0
# Source           0
# Demographic      0
# Producers        0
# dtype: int64

# %%
# Fill missing in categorical columns with 'Unknown' or 'Ongoing'

df['Tv'] = df['Tv'].fillna('Unknown')
df['Ed'] = df['Ed'].fillna('Ongoing')

# For Episodes, either keep NaN or fill with 'Unknown'
df['Ep'] = df['Ep'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# Titles         0
# Tv             0
# Ep             0
# SD             0
# Ed             0
# Ratings        0
# Genres         0
# Source         0
# Demographic    0
# Producers      0
# dtype: int64

# %%
df.head()
# Out:
#                                Titles     Tv       Ep        SD        Ed  \
# 0    Fullmetal Alchemist: Brotherhood     TV   64 eps  Apr 2009  Jul 2010
# 1                         Steins;Gate     TV   24 eps  Apr 2011  Sep 2011
# 2                            Gintama°     TV   51 eps  Apr 2015  Mar 2016
# 3  Shingeki no Kyojin Season 3 Part 2     TV   10 eps  Apr 2019  Jul 2019
# 4                  Gintama: The Final  Movie  Unknown  Jan 2021  Jan 2021
#
#    Ratings                                             Genres Source  \
# 0     9.09  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...  Manga
# 1     9.07  ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...  Drama
# 2     9.06  ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...  Manga
# 3     9.05  ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...  Manga
# 4     9.04  ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...  Manga
#
#      Demographic                                          Producers
# 0        Shounen  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1  Not specified  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 2        Shounen                  ['TV Tokyo', 'Aniplex', 'Dentsu']
# 3        Shounen  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 4        Shounen  ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...

# %%
df['Ep_num'] = pd.to_numeric(df["Ep"], errors = 'coerce')

# %%
print(df[['Ep', 'Ep_num']].head(15))


print("\nMissing after conversion:", df['Ep_num'].isna().sum())
# Out:
#          Ep  Ep_num
# 0    64 eps     NaN
# 1    24 eps     NaN
# 2    51 eps     NaN
# 3    10 eps     NaN
# 4   Unknown     NaN
# 5    51 eps     NaN
# 6   Unknown     NaN
# 7   Unknown     NaN
# 8    13 eps     NaN
# 9    13 eps     NaN
# 10   13 eps     NaN
# 11   12 eps     NaN
# 12   13 eps     NaN
# 13  Unknown     NaN
# 14  Unknown     NaN
#
# Missing after conversion: 400

# %%
df
# Out:
#                                                 Titles       Tv       Ep  \
# 0                     Fullmetal Alchemist: Brotherhood       TV   64 eps
# 1                                          Steins;Gate       TV   24 eps
# 2                                             Gintama°       TV   51 eps
# 3                   Shingeki no Kyojin Season 3 Part 2       TV   10 eps
# 4                                   Gintama: The Final    Movie  Unknown
# ..                                                 ...      ...      ...
# 395                                    Ashita no Joe 2       TV   47 eps
# 396  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...       TV   12 eps
# 397                                 Mob Psycho 100 III       TV   12 eps
# 398  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...  Unknown  Unknown
# 399                                          86 Part 2       TV   12 eps
#
#            SD        Ed  Ratings  \
# 0    Apr 2009  Jul 2010     9.09
# 1    Apr 2011  Sep 2011     9.07
# 2    Apr 2015  Mar 2016     9.06
# 3    Apr 2019  Jul 2019     9.05
# 4    Jan 2021  Jan 2021     9.04
# ..        ...       ...      ...
# 395  Oct 1980  Aug 1981     8.72
# 396  Jan 2017  Mar 2017     8.71
# 397  Oct 2022  Dec 2022     8.71
# 398  Feb 1999  Sep 1999     8.70
# 399  Oct 2021  Mar 2022     8.70
#
#                                                 Genres       Source  \
# 0    ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...        Manga
# 1    ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...        Drama
# 2    ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...        Manga
# 3    ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...        Manga
# 4    ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...        Manga
# ..                                                 ...          ...
# 395    ['Drama', 'Sports', 'Combat Sports', 'Shounen']        Manga
# 396  ['Drama', 'Adult Cast', 'Historical', 'Love Po...        Manga
# 397  ['Action', 'Comedy', 'Supernatural', 'Super Po...    Web manga
# 398  ['Action', 'Drama', 'Romance', 'Adult Cast', '...        Manga
# 399  ['Action', 'Drama', 'Sci-Fi', 'Mecha', 'Milita...  Light novel
#
#        Demographic                                          Producers  Ep_num
# 0          Shounen  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...     NaN
# 1    Not specified  ['Frontier Works', 'Media Factory', 'Kadokawa ...     NaN
# 2          Shounen                  ['TV Tokyo', 'Aniplex', 'Dentsu']     NaN
# 3          Shounen  ['Production I.G', 'Dentsu', 'Mainichi Broadca...     NaN
# 4          Shounen  ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...     NaN
# ..             ...                                                ...     ...
# 395        Shounen                                       ['Annapuru']     NaN
# 396          Josei  ['Mainichi Broadcasting System', 'Kodansha', '...     NaN
# 397  Not specified  ['Shogakukan-Shueisha Productions', 'Warner Br...     NaN
# 398        Shounen                                        ['Aniplex']     NaN
# 399  Not specified          ['Aniplex', 'Kadokawa', 'Bandai Spirits']     NaN
#
# [400 rows x 11 columns]

# %%
df['Ep_clean'] = df['Ep'].str.replace('eps', '', regex=False).str.strip()

df['Ep_num'] = pd.to_numeric(df['Ep_clean'], errors='coerce')

print(df[['Ep', 'Ep_clean', 'Ep_num']].head(15))

print("\nMissing after conversion:", df['Ep_num'].isna().sum())
# Out:
#          Ep Ep_clean  Ep_num
# 0    64 eps       64    64.0
# 1    24 eps       24    24.0
# 2    51 eps       51    51.0
# 3    10 eps       10    10.0
# 4   Unknown  Unknown     NaN
# 5    51 eps       51    51.0
# 6   Unknown  Unknown     NaN
# 7   Unknown  Unknown     NaN
# 8    13 eps       13    13.0
# 9    13 eps       13    13.0
# 10   13 eps       13    13.0
# 11   12 eps       12    12.0
# 12   13 eps       13    13.0
# 13  Unknown  Unknown     NaN
# 14  Unknown  Unknown     NaN
#
# Missing after conversion: 124

# %%
df['Episodes_Label'] = df['Ep_num'].fillna('Unknown')

# %%
#df

# %%
# keep Ep_num (numeric) and optionally Episodes_Label, drop original Ep & Ep_clean
df.drop(columns=['Ep', 'Ep_clean'], inplace=True, errors='ignore')

# check columns now

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Titles          400 non-null    object
#  1   Tv              400 non-null    object
#  2   SD              400 non-null    object
#  3   Ed              400 non-null    object
#  4   Ratings         400 non-null    float64
#  5   Genres          400 non-null    object
#  6   Source          400 non-null    object
#  7   Demographic     400 non-null    object
#  8   Producers       400 non-null    object
#  9   Ep_num          276 non-null    float64
#  10  Episodes_Label  400 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 34.5+ KB

# %%
df.head()
# Out:
#                                Titles     Tv        SD        Ed  Ratings  \
# 0    Fullmetal Alchemist: Brotherhood     TV  Apr 2009  Jul 2010     9.09
# 1                         Steins;Gate     TV  Apr 2011  Sep 2011     9.07
# 2                            Gintama°     TV  Apr 2015  Mar 2016     9.06
# 3  Shingeki no Kyojin Season 3 Part 2     TV  Apr 2019  Jul 2019     9.05
# 4                  Gintama: The Final  Movie  Jan 2021  Jan 2021     9.04
#
#                                               Genres Source    Demographic  \
# 0  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...  Manga        Shounen
# 1  ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...  Drama  Not specified
# 2  ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...  Manga        Shounen
# 3  ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...  Manga        Shounen
# 4  ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...  Manga        Shounen
#
#                                            Producers  Ep_num Episodes_Label
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...    64.0           64.0
# 1  ['Frontier Works', 'Media Factory', 'Kadokawa ...    24.0           24.0
# 2                  ['TV Tokyo', 'Aniplex', 'Dentsu']    51.0           51.0
# 3  ['Production I.G', 'Dentsu', 'Mainichi Broadca...    10.0           10.0
# 4  ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...     NaN        Unknown

# %%
import ast

# Convert the string representation of list into an actual Python list
df['Genres_list'] = df['Genres'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# Quick check first rows
df[['Genres', 'Genres_list']].head()
# Out:
#                                               Genres  \
# 0  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...
# 1  ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...
# 2  ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...
# 3  ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...
# 4  ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...
#
#                                          Genres_list
# 0  [Action, Adventure, Drama, Fantasy, Military, ...
# 1  [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 2  [Action, Comedy, Sci-Fi, Gag Humor, Historical...
# 3  [Action, Drama, Suspense, Gore, Military, Surv...
# 4  [Action, Comedy, Drama, Sci-Fi, Gag Humor, His...

# %%
df['Producers_list'] = df['Producers'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# %%
df
# Out:
#                                                 Titles       Tv        SD  \
# 0                     Fullmetal Alchemist: Brotherhood       TV  Apr 2009
# 1                                          Steins;Gate       TV  Apr 2011
# 2                                             Gintama°       TV  Apr 2015
# 3                   Shingeki no Kyojin Season 3 Part 2       TV  Apr 2019
# 4                                   Gintama: The Final    Movie  Jan 2021
# ..                                                 ...      ...       ...
# 395                                    Ashita no Joe 2       TV  Oct 1980
# 396  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...       TV  Jan 2017
# 397                                 Mob Psycho 100 III       TV  Oct 2022
# 398  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...  Unknown  Feb 1999
# 399                                          86 Part 2       TV  Oct 2021
#
#            Ed  Ratings                                             Genres  \
# 0    Jul 2010     9.09  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...
# 1    Sep 2011     9.07  ['Drama', 'Sci-Fi', 'Suspense', 'Psychological...
# 2    Mar 2016     9.06  ['Action', 'Comedy', 'Sci-Fi', 'Gag Humor', 'H...
# 3    Jul 2019     9.05  ['Action', 'Drama', 'Suspense', 'Gore', 'Milit...
# 4    Jan 2021     9.04  ['Action', 'Comedy', 'Drama', 'Sci-Fi', 'Gag H...
# ..        ...      ...                                                ...
# 395  Aug 1981     8.72    ['Drama', 'Sports', 'Combat Sports', 'Shounen']
# 396  Mar 2017     8.71  ['Drama', 'Adult Cast', 'Historical', 'Love Po...
# 397  Dec 2022     8.71  ['Action', 'Comedy', 'Supernatural', 'Super Po...
# 398  Sep 1999     8.70  ['Action', 'Drama', 'Romance', 'Adult Cast', '...
# 399  Mar 2022     8.70  ['Action', 'Drama', 'Sci-Fi', 'Mecha', 'Milita...
#
#           Source    Demographic  \
# 0          Manga        Shounen
# 1          Drama  Not specified
# 2          Manga        Shounen
# 3          Manga        Shounen
# 4          Manga        Shounen
# ..           ...            ...
# 395        Manga        Shounen
# 396        Manga          Josei
# 397    Web manga  Not specified
# 398        Manga        Shounen
# 399  Light novel  Not specified
#
#                                              Producers  Ep_num Episodes_Label  \
# 0    ['Aniplex', 'Square Enix', 'Mainichi Broadcast...    64.0           64.0
# 1    ['Frontier Works', 'Media Factory', 'Kadokawa ...    24.0           24.0
# 2                    ['TV Tokyo', 'Aniplex', 'Dentsu']    51.0           51.0
# 3    ['Production I.G', 'Dentsu', 'Mainichi Broadca...    10.0           10.0
# 4    ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...     NaN        Unknown
# ..                                                 ...     ...            ...
# 395                                       ['Annapuru']    47.0           47.0
# 396  ['Mainichi Broadcasting System', 'Kodansha', '...    12.0           12.0
# 397  ['Shogakukan-Shueisha Productions', 'Warner Br...    12.0           12.0
# 398                                        ['Aniplex']     NaN        Unknown
# 399          ['Aniplex', 'Kadokawa', 'Bandai Spirits']    12.0           12.0
#
#                                            Genres_list  \
# 0    [Action, Adventure, Drama, Fantasy, Military, ...
# 1    [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 2    [Action, Comedy, Sci-Fi, Gag Humor, Historical...
# 3    [Action, Drama, Suspense, Gore, Military, Surv...
# 4    [Action, Comedy, Drama, Sci-Fi, Gag Humor, His...
# ..                                                 ...
# 395            [Drama, Sports, Combat Sports, Shounen]
# 396  [Drama, Adult Cast, Historical, Love Polygon, ...
# 397        [Action, Comedy, Supernatural, Super Power]
# 398  [Action, Drama, Romance, Adult Cast, Historica...
# 399           [Action, Drama, Sci-Fi, Mecha, Military]
#
#                                         Producers_list
# 0    [Aniplex, Square Enix, Mainichi Broadcasting S...
# 1    [Frontier Works, Media Factory, Kadokawa Shote...
# 2                          [TV Tokyo, Aniplex, Dentsu]
# 3    [Production I.G, Dentsu, Mainichi Broadcasting...
# 4    [TV Tokyo, Aniplex, Dentsu, Bandai, Warner Bro...
# ..                                                 ...
# 395                                         [Annapuru]
# 396  [Mainichi Broadcasting System, Kodansha, DAX P...
# 397  [Shogakukan-Shueisha Productions, Warner Bros....
# 398                                          [Aniplex]
# 399                [Aniplex, Kadokawa, Bandai Spirits]
#
# [400 rows x 13 columns]

# %% [markdown]
# ### Convert SD and Ed to datetime

# %%
df['SD_date'] = pd.to_datetime(df['SD'], format='%b %Y', errors='coerce')
df['Ed_date'] = pd.to_datetime(df['Ed'], format='%b %Y', errors='coerce')

df[['SD','SD_date','Ed','Ed_date']].head(10)
# Out:
#          SD    SD_date        Ed    Ed_date
# 0  Apr 2009 2009-04-01  Jul 2010 2010-07-01
# 1  Apr 2011 2011-04-01  Sep 2011 2011-09-01
# 2  Apr 2015 2015-04-01  Mar 2016 2016-03-01
# 3  Apr 2019 2019-04-01  Jul 2019 2019-07-01
# 4  Jan 2021 2021-01-01  Jan 2021 2021-01-01
# 5  Apr 2011 2011-04-01  Mar 2012 2012-03-01
# 6  Oct 2011 2011-10-01  Sep 2014 2014-09-01
# 7  Jan 1988 1988-01-01  Mar 1997 1997-03-01
# 8  Oct 2012 2012-10-01  Mar 2013 2013-03-01
# 9  Oct 2022 2022-10-01  Dec 2022 2022-12-01

# %%
# make everything title case or consistent
df['Tv'] = df['Tv'].str.title()
df['Source'] = df['Source'].str.title()
df['Demographic'] = df['Demographic'].str.title()

# optional: replace 'Not Specified' with 'Unknown'
df['Demographic'] = df['Demographic'].replace('Not Specified','Unknown')

# %%
df.drop(columns=['SD','Ed','Genres','Producers'], inplace=True)

# %%
df
# Out:
#                                                 Titles       Tv  Ratings  \
# 0                     Fullmetal Alchemist: Brotherhood       Tv     9.09
# 1                                          Steins;Gate       Tv     9.07
# 2                                             Gintama°       Tv     9.06
# 3                   Shingeki no Kyojin Season 3 Part 2       Tv     9.05
# 4                                   Gintama: The Final    Movie     9.04
# ..                                                 ...      ...      ...
# 395                                    Ashita no Joe 2       Tv     8.72
# 396  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...       Tv     8.71
# 397                                 Mob Psycho 100 III       Tv     8.71
# 398  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...  Unknown     8.70
# 399                                          86 Part 2       Tv     8.70
#
#           Source Demographic  Ep_num Episodes_Label  \
# 0          Manga     Shounen    64.0           64.0
# 1          Drama     Unknown    24.0           24.0
# 2          Manga     Shounen    51.0           51.0
# 3          Manga     Shounen    10.0           10.0
# 4          Manga     Shounen     NaN        Unknown
# ..           ...         ...     ...            ...
# 395        Manga     Shounen    47.0           47.0
# 396        Manga       Josei    12.0           12.0
# 397    Web Manga     Unknown    12.0           12.0
# 398        Manga     Shounen     NaN        Unknown
# 399  Light Novel     Unknown    12.0           12.0
#
#                                            Genres_list  \
# 0    [Action, Adventure, Drama, Fantasy, Military, ...
# 1    [Drama, Sci-Fi, Suspense, Psychological, Time ...
# 2    [Action, Comedy, Sci-Fi, Gag Humor, Historical...
# 3    [Action, Drama, Suspense, Gore, Military, Surv...
# 4    [Action, Comedy, Drama, Sci-Fi, Gag Humor, His...
# ..                                                 ...
# 395            [Drama, Sports, Combat Sports, Shounen]
# 396  [Drama, Adult Cast, Historical, Love Polygon, ...
# 397        [Action, Comedy, Supernatural, Super Power]
# 398  [Action, Drama, Romance, Adult Cast, Historica...
# 399           [Action, Drama, Sci-Fi, Mecha, Military]
#
#                                         Producers_list    SD_date    Ed_date
# 0    [Aniplex, Square Enix, Mainichi Broadcasting S... 2009-04-01 2010-07-01
# 1    [Frontier Works, Media Factory, Kadokawa Shote... 2011-04-01 2011-09-01
# 2                          [TV Tokyo, Aniplex, Dentsu] 2015-04-01 2016-03-01
# 3    [Production I.G, Dentsu, Mainichi Broadcasting... 2019-04-01 2019-07-01
# 4    [TV Tokyo, Aniplex, Dentsu, Bandai, Warner Bro... 2021-01-01 2021-01-01
# ..                                                 ...        ...        ...
# 395                                         [Annapuru] 1980-10-01 1981-08-01
# 396  [Mainichi Broadcasting System, Kodansha, DAX P... 2017-01-01 2017-03-01
# 397  [Shogakukan-Shueisha Productions, Warner Bros.... 2022-10-01 2022-12-01
# 398                                          [Aniplex] 1999-02-01 1999-09-01
# 399                [Aniplex, Kadokawa, Bandai Spirits] 2021-10-01 2022-03-01
#
# [400 rows x 11 columns]

# %%
# Save cleaned dataframe to CSV
df.to_csv('Cleaned_Anime_Data_1.csv', index=False)

# %% [markdown]
# ### 📝 Steps We Performed
#
# Loaded raw data using pandas.read_csv().
#
# Dropped unnecessary index column (Unnamed: 0).
#
# Standardized string columns (removed extra spaces, consistent case).
#
# Handled missing values:
#
# Converted “Unknown” / “Not specified” in Demographic to NaN.
#
# For movies, filled missing Ep_num with 1.
#
# Split list-like columns (Genres & Producers) into proper Python lists.
#
# Converted dates in SD & Ed columns to datetime objects.
#
# Standardized list entries: stripped spaces & consistent casing for genres/producers.
